# %%
from simulation.ValueMapStorage import ValueMapStorage
from simulation.simulation_globals import CAPACITY
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets

storage = ValueMapStorage(CAPACITY, 0.5, 60, '.\\Kennfeld_WR.CSV', '.\\BatterieKennfeldNeu_60s_Fl.mat')

socs = []
for i in range(30000):
    storage.scheduled_power_ac = 600 * (-1 if (i//500)%2 == 0 else 1 )
    storage.step()
    socs.append(storage.soc())
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(socs[:])
print(np.mean(socs))
# Out:
# 0.43950848651463653

# %% [markdown]
# ## Headline
# # Headline
#
# Hallo Das ist Text
#
# $$y = x^3$$
